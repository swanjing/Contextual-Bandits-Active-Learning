# %%
# !conda activate deepCB

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import pickle
import os

# %%
rs = list()
uslc = list()
ussm = list()
usen = list()
reps = list()
albl = list()
mbal = list()
ubal = list()
cbal = list()
cbalT = list()
mbalC = list()
cbalC = list()
cbalCT = list()
cbalf1 = list()

# %%
fnames = ['rsBiome1','rsBiome2','rsBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    rs.append(tp)
    
fnames = ['uslcBiome1','uslcBiome2','uslcBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    uslc.append(tp)
    
fnames = ['ussmBiome1','ussmBiome2','ussmBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    ussm.append(tp)
    
fnames = ['usenBiome1','usenBiome2','usenBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    usen.append(tp)
    
fnames = ['repsBiome1','repsBiome2','repsBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    reps.append(tp)
    
fnames = ['alblBiome1','alblBiome2','alblBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    albl.append(tp)
    
fnames = ['mbalBiome1','mbalBiome2','mbalBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    mbal.append(tp)
     
fnames = ['ubalBiome1','ubalBiome2','ubalBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    ubal.append(tp)
    
fnames = ['cbalBiome1','cbalBiome2','cbalBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    cbal.append(tp)
    
fnames = ['cbalTBiome1','cbalTBiome2','cbalTBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    cbalT.append(tp)
    
fnames = ['cbalCBiome1','cbalCBiome2','cbalCBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    cbalC.append(tp)
    
fnames = ['mbalCBiome1','mbalCBiome2','mbalCBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    mbalC.append(tp)
    
fnames = ['cbalCTBiome1','cbalCTBiome2','cbalCTBiome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    cbalCT.append(tp)
    
fnames = ['cbalf1Biome1','cbalf1Biome2','cbalf1Biome3']
for name in fnames:
    fname = name+'.txt'
    ifile = open(fname,'rb')
    tp, _ = pickle.load(ifile)
    ifile.close()
    cbalf1.append(tp)

# %%
met = 'testing_f1'
rste = list()
for x in rs:
    rste.append(np.array(x[met]))
rste = np.array(rste)

uslcte = list()
for x in uslc:
    uslcte.append(np.array(x[met]))
uslcte = np.array(uslcte)

ussmte = list()
for x in ussm:
    ussmte.append(np.array(x[met]))
ussmte = np.array(ussmte)

usente = list()
for x in usen:
    usente.append(np.array(x[met]))
usente = np.array(usente)

repste = list()
for x in reps:
    repste.append(np.array(x[met]))
repste = np.array(repste)

alblte = list()
for x in albl:
    alblte.append(np.array(x[met]))
alblte = np.array(alblte)

mbalte = list()
for x in mbal:
    mbalte.append(np.array(x[met]))
mbalte = np.array(mbalte)

ubalte = list()
for x in ubal:
    ubalte.append(np.array(x[met]))
ubalte = np.array(ubalte)

cbalte = list()
for x in cbal:
    cbalte.append(np.array(x[met]))
cbalte = np.array(cbalte)

cbalTte = list()
for x in cbalT:
    cbalTte.append(np.array(x[met]))
cbalTte = np.array(cbalTte)

cbalCte = list()
for x in cbalC:
    cbalCte.append(np.array(x[met]))
cbalCte = np.array(cbalCte)

mbalCte = list()
for x in mbalC:
    mbalCte.append(np.array(x[met]))
mbalCte = np.array(mbalCte)

cbalCTte = list()
for x in cbalCT:
    cbalCTte.append(np.array(x[met]))
cbalCTte = np.array(cbalCTte)

cbalf1te = list()
for x in cbalf1:
    cbalf1te.append(np.array(x[met]))
cbalf1te = np.array(cbalf1te)

# %%
for x in [rste,uslcte,ussmte,usente,repste,alblte,mbalte,ubalte,cbalte,cbalTte,cbalCte,mbalCte,cbalCTte,cbalf1te]:
    print(np.max(x), np.max(np.mean(x, axis=0)))
# Out:
# 0.3759519145786303
# 0.35594755467981426
# 0.3800905436707733
# 0.3824188148375705
# 0.38626398816057333

# %%
plt.rcParams.update({'font.size': 15})

# %%
query_num = range(1,150+1)
plt.figure(figsize=(10,7))
# plt.plot(query_num, np.mean(rste, axis=0), 'grey', label='Random', linewidth=2)
# plt.plot(query_num, np.mean(uslcte, axis=0), 'sandybrown', label='Least Confidence', linewidth=2)
# plt.plot(query_num, np.mean(ussmte, axis=0), 'lightcoral', label='Smallest Margin', linewidth=2)
# plt.plot(query_num, np.mean(usente, axis=0), 'chocolate', label='Entropy', linewidth=2)
# plt.plot(query_num, np.mean(repste, axis=0), 'olivedrab', label='RepSamp', linewidth=2)
# plt.plot(query_num, np.mean(alblte, axis=0), 'royalblue', label='ALBL', linewidth=2)
# plt.plot(query_num, np.mean(mbalte, axis=0), 'skyblue', label='MBAL', linewidth=2)
# plt.plot(query_num, np.mean(ubalte, axis=0), 'teal', label='UBAL', linewidth=2)
plt.plot(query_num, np.mean(cbalte, axis=0), 'salmon', label='CBAL', linewidth=2)
# plt.plot(query_num, np.mean(cbalTte, axis=0), 'b', label='CBAL Trained', linewidth=2)
plt.plot(query_num, np.mean(cbalCte, axis=0), 'm', label='CBAL Custom', linewidth=2)
# plt.plot(query_num, np.mean(mbalCte, axis=0), 'g', label='MBAL Custom', linewidth=2)
# plt.plot(query_num, np.mean(cbalCTte, axis=0), 'b', label='CBALCT', linewidth=2)
# plt.plot(query_num, np.mean(cbalf1te, axis=0), 'g', label='CBALf1', linewidth=2)


plt.xlabel('Query Round')
plt.ylabel(met)
plt.title('Experiment Result; Testing F1')
# plt.title(met)
plt.legend(loc='lower right')
# plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
#             fancybox=True, shadow=True, ncol=5)
plt.show()
